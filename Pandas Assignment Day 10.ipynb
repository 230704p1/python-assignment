# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

print("Successfully installed!")
# Out:
# Successfully installed!

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
a = pd.Series([100,200,300,400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.Series'>

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
print(a[2])
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
print(a.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['a','b','c','d']

# %% [markdown]
# Access the value in the series with index 'd'

# %%
print(a['d'])
# Out:
# 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
b = pd.Series([400, 500, 600], index=['x', 'y', 'z'])
print(b)
# Out:
# x    400
# y    500
# z    600
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
# b = 

b = pd.Series([800, 450, 100], index=['e', 'f', 'g'])
print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
import pandas as pd
a = pd.Series([100, 200, 300, 400], index=['a', 'b', 'c','d'])
b = pd.Series([800, 450, 100], index=['e', 'f', 'g'])

c = pd.concat([a, b])
print(c)
# Out:
# a    100
# b    200
# c    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %%
#print a again after appending b into it

print(c)
# Out:
# a    100
# b    200
# c    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
a = a.sort_values(ascending=False)

# %%
print(a.index)
# Out:
# Index(['d', 'c', 'b', 'a'], dtype='str')

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
df = pd.DataFrame(c)
print(df)
# Out:
#      0
# a  100
# b  200
# c  300
# d  400
# e  800
# f  450
# g  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
print(df.shape)
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
print(df.head())
print(df.tail())
# Out:
#      0
# a  100
# b  200
# c  300
# d  400
# e  800
#      0
# c  300
# d  400
# e  800
# f  450
# g  100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df.columns = ['points']
print(df)
# Out:
#    points
# a     100
# b     200
# c     300
# d     400
# e     800
# f     450
# g     100

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array

import numpy as np

fruits_array = np.random.choice(['orange', 'mango', 'apple'], size=7)
print(fruits_array)
# Out:
# ['mango' 'mango' 'apple' 'mango' 'apple' 'apple' 'mango']

# %%
#Create series fruits out of fruits array

fruits = pd.Series(fruits_array)
print(fruits)
# Out:
# 0    mango
# 1    mango
# 2    apple
# 3    mango
# 4    apple
# 5    apple
# 6    mango
# dtype: str

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index = df.index
print(fruits)
# Out:
# a    mango
# b    mango
# c    apple
# d    mango
# e    apple
# f    apple
# g    mango
# dtype: str

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits'] = fruits
print(df.head())
# Out:
#    points fruits
# a     100  mango
# b     200  mango
# c     300  apple
# d     400  mango
# e     800  apple

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
import pandas as pd

d1 = pd.DataFrame({
    'city': ['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'],
    'Temperature': [15, 22, 20, 26, 2]
})

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali            2

# %% [markdown]
# What is the shape of d1.

# %%
print(d1.shape)
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: str
# <class 'pandas.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
import pandas as pd
d2 = pd.DataFrame({'city' : ['Bengalaru','Coimbatore','Srirangam','Pondicherry'], 
'Temperature' : [24,35,36,39]})

# %% [markdown]
# print the shape of this dataframe

# %%
print(d2.shape)
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
d3 = pd.concat([d1, d2], ignore_index=True)
print(d3)
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali            2
# 5    Bengalaru           24
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
low_temp = d3[d3['Temperature'] <= 20]
print(low_temp)
print("Count:", len(low_temp))
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali            2
# Count: 3

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
high_temp = d3[d3['Temperature'] >= 35]
print(high_temp)
# Out:
#           city  Temperature
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
def is_ut(city):
    ut_list = ['Chandigarh', 'Delhi', 'Pondicherry']
    return city in ut_list

d3['Is_Union_Territory'] = d3['city'].apply(is_ut)

# %%
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali            2  False
# 5    Bengalaru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here
def c_to_f(temp):
    return (temp * 9/5) + 32

# %%
# check function c_to_f(10)

print(c_to_f(10))
# Out:
# 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'

d3['temp_fahrenheit'] = d3['Temperature'].apply(c_to_f)
print(d3)
# Out:
#           city  Temperature  is_ut  temp_fahrenheit
# 0   Chandigarh           15   True             59.0
# 1        Delhi           22   True             71.6
# 2       Kanpur           20  False             68.0
# 3      Chennai           26  False             78.8
# 4       Manali            2  False             35.6
# 5    Bengalaru           24  False             75.2
# 6   Coimbatore           35  False             95.0
# 7    Srirangam           36  False             96.8
# 8  Pondicherry           39   True            102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
# print(d3.columns)

ut_cities = d3[d3['Is_Union_Territory'] == True]
print(ut_cities)
# Out:
#           city  Temperature  is_ut  temp_fahrenheit  Is_Union_Territory
# 0   Chandigarh           15   True             59.0                True
# 1        Delhi           22   True             71.6                True
# 8  Pondicherry           39   True            102.2                True

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
high_temp_f = d3[d3['temp_fahrenheit'] > 90]
print(high_temp_f)
# Out:
#           city  Temperature  is_ut  temp_fahrenheit
# 6   Coimbatore           35  False             95.0
# 7    Srirangam           36  False             96.8
# 8  Pondicherry           39   True            102.2

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
print(d3.head(3))
# Out:
#          city  Temperature  is_ut  temp_fahrenheit
# 0  Chandigarh           15   True             59.0
# 1       Delhi           22   True             71.6
# 2      Kanpur           20  False             68.0

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
print(d3.iloc[:, -2:])
# Out:
#    is_ut  temp_fahrenheit
# 0   True             59.0
# 1   True             71.6
# 2  False             68.0
# 3  False             78.8
# 4  False             35.6
# 5  False             75.2
# 6  False             95.0
# 7  False             96.8
# 8   True            102.2

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

data = pd.DataFrame({
    'city': ['Delhi', 'Delhi', 'Mumbai', 'Mumbai', 'Chennai'],
    'Temperature': [30, 35, 32, 36, 33]
})
# Out:
# city
# Chennai    33.0
# Delhi      32.5
# Mumbai     34.0
# Name: Temperature, dtype: float64

# %%
# Use Groupby of single column with aggregate sum()

grouped = data.groupby('city')['Temperature'].mean()
print(grouped)
# Out:
# city
# Chennai    33.0
# Delhi      32.5
# Mumbai     34.0
# Name: Temperature, dtype: float64

# %%
# Use Groupby of single column with aggregate count()

grouped_count = data.groupby('city')['Temperature'].count()
print(grouped_count)
# Out:
# city
# Chennai    1
# Delhi      2
# Mumbai     2
# Name: Temperature, dtype: int64

# %%
# Use Groupby of single column with aggregate count()
grouped_count = data.groupby('city')['Temperature'].count()
print(grouped_count)
# Out:
# city
# Chennai    1
# Delhi      2
# Mumbai     2
# Name: Temperature, dtype: int64

# %%
# Use Groupby of any 2 columns with aggregate mean()

data2 = pd.DataFrame({
    'city': ['Delhi', 'Delhi', 'Mumbai', 'Mumbai', 'Chennai'],
    'day': ['Mon', 'Tue', 'Mon', 'Tue', 'Mon'],
    'Temperature': [30, 35, 32, 36, 33]
})

# %%
# Use Groupby of any 2 columns with aggregate mean()

grouped_mean = data2.groupby(['city', 'day'])['Temperature'].mean()
print(grouped_mean)
# Out:
# city     day
# Chennai  Mon    33.0
# Delhi    Mon    30.0
#          Tue    35.0
# Mumbai   Mon    32.0
#          Tue    36.0
# Name: Temperature, dtype: float64

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
import pandas as pd

a = pd.date_range(start='2020-01-01', end='2021-04-01')

# %% [markdown]
# print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[us]', length=457, freq='D')

# %% [markdown]
# What is the len of a?

# %%
print(len(a))
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
print(type(a))
# Out:
# <class 'pandas.DatetimeIndex'>
